# %%
import pandas as pd
import os
import csv
import re
import ftfy
import unicodedata
from collections import Counter
from tokenizers import Tokenizer
from tokenizers.models import BPE
from tokenizers.pre_tokenizers import ByteLevel
from tokenizers.trainers import BpeTrainer
from tokenizers.processors import TemplateProcessing
from tokenizers import Tokenizer
import torch
import torch.nn as nn
from torch.nn import functional as F
import numpy as np
from sklearn.model_selection import train_test_split
import time

torch.manual_seed(42)

BATCH_SIZE     = 64
CONTEXT_SIZE   = 256
MAX_ITERS      = 3000
EVAL_INTERVAL  = 100
LR_RATE        = 3e-4
EVAL_ITERS     = 10
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
data = pd.read_csv(r'..\data\processed\final_cleaned_jokes.csv')
data = data[data.joke_cleaned.notnull()]

# %%
tokenizer = Tokenizer.from_file(
    r'..\data\processed\tokenizer.json'
)

# %%
data
# Out:
#            rid                                 stable_id  \
# 0            1  0000066daaacde54c609a69be4f00c3336480137
# 1            2  00000a79878b3729adc0e47a34dbf5d5484214c0
# 2            3  000054bc76448f9b302e6266a72324ecb81d4083
# 3            4  0000b76ab05f5d5cf9952d109c5ce7b143ae016f
# 4            5  00015c7571451cc5eb99c24dd7bc46a5ce46b9a1
# ...        ...                                       ...
# 726782  726783  ffff42e7a4d6a0ba5d6d548400c2786eca9609c4
# 726783  726784  ffff4cf4bb9b9e63636efbb0692d20ea00257b64
# 726784  726785  ffff621a689a09dd38aef56fc93b58fba9efd948
# 726785  726786  ffff6e0d16c8de3d9c1c9a1100747ab55f8d6e5f
# 726786  726787  ffff6e22c40c51fa41c6bbaa04ac8299f1eb5614
#
#                                                      joke  \
# 0       Whoever said imitation is the sincerest form o...
# 1       You're so fat, they oughta call your dick gary...
# 2       I couldn't sleep last night. I was wondering w...
# 3                              What's 11 & 2? The Cowboys
# 4       I just got done apologizing to my barbershop q...
# ...                                                   ...
# 726782  There were three dinosaurs who found a magic l...
# 726783  What was the hardest part about Michael Jackso...
# 726784               My dick is called life. Life is hard
# 726785  What was Jeffrey Epstein humming before dying?...
# 726786  What was the allergic 2x4's terrifying halluci...
#
#                               topic  \
# 0       imitation, flattery, minute
# 1                oldman, dick, gary
# 2                        night, sun
# 3                           cowboys
# 4       barbershop, quartet, bucket
# ...                             ...
# 726782      dinosaur, shower, genie
# 726783  michael, jackson, autograph
# 726784                   life, dick
# 726785   republic, jeffrey, epstein
# 726786           hallucination, 2x4
#
#                                              joke_cleaned  word_count
# 0       whoever said imitation is the sincerest form o...          23
# 1       you're so fat , they oughta call your dick gar...          20
# 2       i couldn't sleep last night . i was wondering ...          18
# 3                               what's 11 2 ? the cowboys           6
# 4       i just got done apologizing to my barbershop q...          34
# ...                                                   ...         ...
# 726782  there were three dinosaurs who found a magic l...          70
# 726783  what was the hardest part about michael jackso...          18
# 726784              my dick is called life . life is hard           9
# 726785  what was jeffrey epstein humming before dying ...          17
# 726786  what was the allergic 2x4's terrifying halluci...          11
#
# [726786 rows x 6 columns]

# %%
encoded = tokenizer.encode(f"tell me a joke about {data.topic[0]}",data.joke_cleaned[0])
print(encoded.tokens)
print(encoded.ids)
print(tokenizer.decode(encoded.ids, skip_special_tokens=False))
# Out:
# ['[S]', 'Ġtell', 'Ġme', 'Ġa', 'Ġjoke', 'Ġabout', 'Ġimitation', ',', 'Ġflattery', ',', 'Ġminute', '[JOKE]', 'Ġwhoever', 'Ġsaid', 'Ġimitation', 'Ġis', 'Ġthe', 'Ġsincerest', 'Ġform', 'Ġof', 'Ġflattery', 'Ġhasn', "'t", 'Ġhad', 'Ġa', 'Ġ7', 'yo', 'Ġmim', 'icking', 'Ġtheir', 'Ġevery', 'Ġword', 'Ġfor', 'Ġthe', 'Ġlast', 'Ġ10', 'Ġminutes', 'Ġ.', '[/S]']
# [0, 373, 140, 56, 403, 249, 22485, 12, 18861, 12, 2107, 6, 4522, 234, 22485, 127, 61, 23633, 2996, 110, 18861, 3060, 148, 303, 56, 967, 4546, 16712, 2158, 387, 365, 793, 157, 61, 522, 782, 1021, 62, 1]
# [S] tell me a joke about imitation, flattery, minute[JOKE] whoever said imitation is the sincerest form of flattery hasn't had a 7yo mimicking their every word for the last 10 minutes .[/S]

# %%
sequences = [f"tell me a joke about {t} [JOKE] {j}" 
             for t,j in zip(data.topic, data.joke_cleaned)]

# %%
tokenized = tokenizer.encode_batch(sequences)

# %%
tokenized_ids = [x.ids for x in tokenized]

# %%
tokenized_ids = torch.tensor(tokenized_ids)

# %%
tokenized_ids.shape
# Out:
# torch.Size([726786, 256])

# %%
data_len = len(tokenized_ids)
train_data = tokenized_ids[:int(data_len*.9)]
test_data  = tokenized_ids[int(data_len*.9):]

# %%
PAD_TOKEN_ID = tokenizer.token_to_id("[PAD]")
PAD_TOKEN_ID
# Out:
# 2

# %%
train_data
# Out:
# tensor([[  0, 373, 140,  ...,   2,   2,   2],
#         [  0, 373, 140,  ...,   2,   2,   2],
#         [  0, 373, 140,  ...,   2,   2,   2],
#         ...,
#         [  0, 373, 140,  ...,   2,   2,   2],
#         [  0, 373, 140,  ...,   2,   2,   2],
#         [  0, 373, 140,  ...,   2,   2,   2]])

# %%
tokenizer = Tokenizer.from_file(
    r'..\data\processed\tokenizer.json'
)

# %%
PAD_TOKEN_ID = tokenizer.token_to_id("[PAD]")
PAD_TOKEN_ID
# Out:
# 2

# %%
def get_tokenized_data():
    cache_path = r'..\data\processed\tokenized_jokes_split.npz'

    if os.path.exists(cache_path):
        print("Loading tokenized data from cache...")
        data = np.load(cache_path)
        train_data = torch.from_numpy(data['train_data'])
        test_data  = torch.from_numpy(data['test_data'])
    else:
        data = pd.read_csv(r'..\data\processed\final_cleaned_jokes.csv')
        data = data[data.joke_cleaned.notnull()]
        tokenizer = Tokenizer.from_file(
            r'..\data\processed\tokenizer.json'
        )
        sequences = [f"tell me a joke about {t} [JOKE] {j}" 
                 for t,j in zip(data.topic, data.joke_cleaned)]
        tokenized = tokenizer.encode_batch(sequences)
        tokenized_ids = [x.ids for x in tokenized]
        tokenized_ids = torch.tensor(tokenized_ids)
        
        data_len = len(tokenized_ids)
        train_data = tokenized_ids[:int(data_len*.9)]
        test_data  = tokenized_ids[int(data_len*.9):]
        np.savez_compressed(
            cache_path,
            train_data=train_data.numpy(),
            test_data=test_data.numpy()
        )
    return train_data, test_data

train_data, test_data = get_tokenized_data()
# Out:
# Loading tokenized data from cache...

# %%
def get_batch(batch_size=4, data='train'):
    dataset = train_data if data=='train' else test_data
    idx = torch.randint(len(train_data), (batch_size,))
    x = train_data[idx]
    y = torch.cat([x[:, 1:], torch.full((batch_size, 1), PAD_TOKEN_ID, dtype=x.dtype)], dim=1)
    x = x.to(device)
    y = y.to(device)
    return x, y
xb, yb = get_batch()
print(xb)
print(yb)
# Out:
# tensor([[  0, 373, 140,  ...,   2,   2,   2],
#         [  0, 373, 140,  ...,   2,   2,   2],
#         [  0, 373, 140,  ...,   2,   2,   2],
#         [  0, 373, 140,  ...,   2,   2,   2]], device='cuda:0')
# tensor([[373, 140,  56,  ...,   2,   2,   2],
#         [373, 140,  56,  ...,   2,   2,   2],
#         [373, 140,  56,  ...,   2,   2,   2],
#         [373, 140,  56,  ...,   2,   2,   2]], device='cuda:0')

# %%
@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(EVAL_ITERS)
        for k in range(EVAL_ITERS):
            X, Y = get_batch(data=split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out


class Head(nn.Module):
    def __init__(self, emb_dim, context_size, head_size, dropout):
        super().__init__()
        self.key   = nn.Linear(emb_dim, head_size, bias=False)
        self.query = nn.Linear(emb_dim, head_size, bias=False)
        self.value = nn.Linear(emb_dim, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(context_size, context_size)))

        self.dropout = nn.Dropout(dropout)

        
    def forward(self, x, attn_mask=None):
        B, T, E = x.shape
        k = self.key(x)    # (B, T, H)
        q = self.query(x)  # (B, T, H)

        weights = q @ k.transpose(-2, -1) * E**-0.5 # (B, T, H) @ (B, H, T) -> (B, T, T)
        weights = weights.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        
        if attn_mask is not None:
            pad_mask = attn_mask[:, None, :].to(weights.device)  # (B, 1, T)
            weights = weights.masked_fill(~pad_mask, float('-inf'))
        
        weights = F.softmax(weights, dim=-1)        # (B, T, T)
        weights = self.dropout(weights)
        
        v = self.value(x)  # (B, T, E)
        out = weights @ v  # (B, T, T) @ (B, T, E) -> (B, T, E)
        return out
    
class MultiHeadAttention(nn.Module):
    def __init__(self, num_heads, emb_dim, context_size, head_size, dropout):
        super().__init__()
        self.heads = nn.ModuleList([
            Head(emb_dim, context_size, head_size, dropout) for _ in range(num_heads)
        ])
        self.proj = nn.Linear(num_heads * head_size, emb_dim)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x, attn_mask=None):
        out = torch.cat([h(x, attn_mask=attn_mask) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

        
class FeedForward(nn.Module):
    def __init__(self, emb_dim, dropout):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(emb_dim, 4 * emb_dim),
            nn.ReLU(),
            nn.Linear(4 * emb_dim, emb_dim),
            nn.Dropout(dropout)
        )

    def forward(self, x):
        return self.net(x)


class Block(nn.Module):
    def __init__(self, emb_dim, context_size, num_heads, dropout):
        super().__init__()
        head_size = emb_dim // num_heads
        self.sa   = MultiHeadAttention(num_heads, emb_dim, context_size, head_size, dropout)
        self.ffwd = FeedForward(emb_dim, dropout)
        self.ln1  = nn.LayerNorm(emb_dim)
        self.ln2  = nn.LayerNorm(emb_dim)
        
    def forward(self, x, attn_mask=None):
        # x + layer because of residual connections
        # deviation from paper -> pre-norm (need to test)
        x = x + self.sa(self.ln1(x), attn_mask=attn_mask)
        x = x + self.ffwd(self.ln2(x))
        return x


class TransformerDecoder(nn.Module):
    def __init__(self, vocab_size, emb_dim, context_size, num_att_heads, dropout):
        super().__init__()
        self.vocab_size = vocab_size
        self.emb_dim = emb_dim
        self.context_size = context_size
        self.token_embedding = nn.Embedding(vocab_size, emb_dim)
        self.position_embedding = nn.Embedding(context_size, emb_dim)

        # self.sa_heads  = MultiHeadAttention(num_att_heads, emb_dim, context_size, head_size=emb_dim//4)

        # self.ffwd = FeedForward(emb_dim)

        self.blocks = nn.ModuleList([
            Block(emb_dim, context_size, num_att_heads, dropout),
            Block(emb_dim, context_size, num_att_heads, dropout),
            Block(emb_dim, context_size, num_att_heads, dropout),
            Block(emb_dim, context_size, num_att_heads, dropout),
            Block(emb_dim, context_size, num_att_heads, dropout),
            Block(emb_dim, context_size, num_att_heads, dropout),
        ])
        self.ln_f = nn.LayerNorm(emb_dim)
        
        self.lm_head = nn.Linear(emb_dim, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape
        token_emb = self.token_embedding(idx) # (B, T, E)
        pos_emb = self.position_embedding(torch.arange(T, device=idx.device)) # (T, E)
        x = token_emb + pos_emb  # (B, T, E)
        # x = self.sa_heads(x)     # (B, T, E)
        # x = self.ffwd(x)         # (B, T, E)

         # Create attention mask: True = keep, False = pad
        attn_mask = (idx != PAD_TOKEN_ID)  # shape (B, T)
    
        for block in self.blocks:
            x = block(x, attn_mask=attn_mask)
        x = self.ln_f(x)
        
        logits = self.lm_head(x) # (B, T, V)
        
        loss = None
        if targets is not None:
            # Flatten both for cross-entropy
            logits = logits.view(B * T, self.vocab_size)
            targets = targets.view(B * T)
            loss = F.cross_entropy(logits, targets, ignore_index=PAD_TOKEN_ID)
        
        return logits, loss

    def generate(self, idx, max_new_tokens=256):
        for _ in range(max_new_tokens):    
            idx_cond = idx[:, -self.context_size:] # when max_new_tokens > context size
            logits, loss = self(idx_cond)
            logits = logits[:, -1, :]
            probs = F.softmax(logits, dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
            idx = torch.cat((idx, idx_next), dim=1)
        return idx

# %%
model = TransformerDecoder(vocab_size=30000, emb_dim=512, context_size=256, num_att_heads=6, dropout=0.2)
model = model.to(device)

# logits, loss = m(xb,  yb)

# %%
pytorch_total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
pytorch_total_params
# Out:
# 49762608

# %%
# model

# %%
model(xb,  yb)
# Out:
# (tensor([[-1.2376e+00, -1.2787e-01,  1.0259e-01,  ...,  5.1747e-01,
#           -3.6349e-01, -2.2395e-01],
#          [-4.7744e-01,  5.4452e-01, -3.1363e-01,  ...,  6.9855e-01,
#           -5.5469e-02,  4.2383e-01],
#          [-1.1620e-01,  2.5012e-01, -1.2868e-01,  ...,  3.1782e-01,
#           -3.5285e-01, -6.3583e-03],
#          ...,
#          [ 6.3681e-01,  4.6941e-01,  5.9799e-01,  ..., -9.5676e-02,
#            6.3363e-01,  5.1541e-04],
#          [ 1.2168e+00, -6.6238e-01,  7.9104e-01,  ..., -4.0072e-02,
#            3.1638e-01, -3.5387e-01],
#          [ 6.3955e-01,  1.0947e-01,  8.8247e-01,  ...,  2.2404e-01,
#            2.7584e-01, -4.7641e-02]], device='cuda:0', grad_fn=<ViewBackward0>),
#  tensor(10.4728, device='cuda:0', grad_fn=<NllLossBackward0>))

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr=LR_RATE)

# %%
batch_size = 32
checkpoint_dir = r'..\data\model_checkpoints'
os.makedirs(checkpoint_dir, exist_ok=True)
a = time.time()
for it in range(10000):

    xb, yb = get_batch(batch_size=batch_size, data='train')

    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
    
    if it % EVAL_INTERVAL == 0:
        losses = estimate_loss()
        print(f"step {it}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")
        ckpt_path = os.path.join(checkpoint_dir, f"checkpoint_{it}.pt")
        torch.save({
            'iteration': it,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': loss.item(),
        }, ckpt_path)
        print(f"[Checkpoint saved] iteration {it} -> {ckpt_path}")
        print(f"Time taken : {time.time() - a}")
        a = time.time()
# Out:
# step 0: train loss 9.4070, val loss 9.4205
# [Checkpoint saved] iteration 0 -> ..\data\model_checkpoints\checkpoint_0.pt
# Time taken : 12.23429536819458
# step 100: train loss 5.0943, val loss 5.0940
# [Checkpoint saved] iteration 100 -> ..\data\model_checkpoints\checkpoint_100.pt
# Time taken : 182.8205440044403
# step 200: train loss 4.9026, val loss 4.8133
# [Checkpoint saved] iteration 200 -> ..\data\model_checkpoints\checkpoint_200.pt
# Time taken : 182.90504837036133
# step 300: train loss 4.5244, val loss 4.9431
# [Checkpoint saved] iteration 300 -> ..\data\model_checkpoints\checkpoint_300.pt
# Time taken : 183.64937949180603
# step 400: train loss 4.6241, val loss 4.5655
# [Checkpoint saved] iteration 400 -> ..\data\model_checkpoints\checkpoint_400.pt
# Time taken : 184.78159070014954
# step 500: train loss 4.5624, val loss 4.5987
# [Checkpoint saved] iteration 500 -> ..\data\model_checkpoints\checkpoint_500.pt
# Time taken : 185.00586342811584
# step 600: train loss 4.4562, val loss 4.6722
# [Checkpoint saved] iteration 600 -> ..\data\model_checkpoints\checkpoint_600.pt
# Time taken : 184.25059914588928
# step 700: train loss 4.0149, val loss 4.2384
# [Checkpoint saved] iteration 700 -> ..\data\model_checkpoints\checkpoint_700.pt
# Time taken : 184.17356252670288
# step 800: train loss 4.2148, val loss 4.6661
# [Checkpoint saved] iteration 800 -> ..\data\model_checkpoints\checkpoint_800.pt
# Time taken : 183.78829860687256
# step 900: train loss 4.3963, val loss 4.3113
# [Checkpoint saved] iteration 900 -> ..\data\model_checkpoints\checkpoint_900.pt
# Time taken : 183.21900248527527
# step 1000: train loss 4.2776, val loss 4.4761
# [Checkpoint saved] iteration 1000 -> ..\data\model_checkpoints\checkpoint_1000.pt
# Time taken : 183.0623848438263
# step 1100: train loss 4.1304, val loss 4.2199
# [Checkpoint saved] iteration 1100 -> ..\data\model_checkpoints\checkpoint_1100.pt
# Time taken : 182.8280439376831
# step 1200: train loss 4.1126, val loss 4.2026
# [Checkpoint saved] iteration 1200 -> ..\data\model_checkpoints\checkpoint_1200.pt
# Time taken : 183.21865844726562
# step 1300: train loss 4.0979, val loss 4.2148
# [Checkpoint saved] iteration 1300 -> ..\data\model_checkpoints\checkpoint_1300.pt
# Time taken : 183.0626721382141
# step 1400: train loss 4.1749, val loss 4.3936
# [Checkpoint saved] iteration 1400 -> ..\data\model_checkpoints\checkpoint_1400.pt
# Time taken : 182.97881817817688
# step 1500: train loss 4.1313, val loss 4.1831
# [Checkpoint saved] iteration 1500 -> ..\data\model_checkpoints\checkpoint_1500.pt
# Time taken : 182.9272541999817
# step 1600: train loss 3.9689, val loss 4.1016
# [Checkpoint saved] iteration 1600 -> ..\data\model_checkpoints\checkpoint_1600.pt
# Time taken : 183.04693150520325
# step 1700: train loss 4.2583, val loss 3.9691
# [Checkpoint saved] iteration 1700 -> ..\data\model_checkpoints\checkpoint_1700.pt
# Time taken : 182.95355033874512
# step 1800: train loss 4.0160, val loss 4.0943
# [Checkpoint saved] iteration 1800 -> ..\data\model_checkpoints\checkpoint_1800.pt
# Time taken : 183.1716446876526
# step 1900: train loss 3.9744, val loss 4.2397
# [Checkpoint saved] iteration 1900 -> ..\data\model_checkpoints\checkpoint_1900.pt
# Time taken : 185.4990131855011
# step 2000: train loss 3.9672, val loss 3.9484
# [Checkpoint saved] iteration 2000 -> ..\data\model_checkpoints\checkpoint_2000.pt
# Time taken : 183.40724754333496
# step 2100: train loss 4.0282, val loss 3.9077
# [Checkpoint saved] iteration 2100 -> ..\data\model_checkpoints\checkpoint_2100.pt
# Time taken : 185.70314121246338
# step 2200: train loss 3.9136, val loss 4.0095
# [Checkpoint saved] iteration 2200 -> ..\data\model_checkpoints\checkpoint_2200.pt
# Time taken : 185.64516639709473
# step 2300: train loss 3.9043, val loss 3.9746
# [Checkpoint saved] iteration 2300 -> ..\data\model_checkpoints\checkpoint_2300.pt
# Time taken : 183.46402525901794
# step 2400: train loss 3.9289, val loss 4.0775
# [Checkpoint saved] iteration 2400 -> ..\data\model_checkpoints\checkpoint_2400.pt
# Time taken : 185.35539197921753
# step 2500: train loss 4.0707, val loss 3.9985
# [Checkpoint saved] iteration 2500 -> ..\data\model_checkpoints\checkpoint_2500.pt
# Time taken : 183.91093158721924
# step 2600: train loss 3.8785, val loss 3.9702
# [Checkpoint saved] iteration 2600 -> ..\data\model_checkpoints\checkpoint_2600.pt
# Time taken : 185.36116194725037
# step 2700: train loss 3.7522, val loss 3.6032
# [Checkpoint saved] iteration 2700 -> ..\data\model_checkpoints\checkpoint_2700.pt
# Time taken : 183.40663290023804
# step 2800: train loss 3.6877, val loss 3.8722
# [Checkpoint saved] iteration 2800 -> ..\data\model_checkpoints\checkpoint_2800.pt
# Time taken : 184.36656641960144
# step 2900: train loss 3.7693, val loss 3.9208
# [Checkpoint saved] iteration 2900 -> ..\data\model_checkpoints\checkpoint_2900.pt
# Time taken : 184.17756485939026
# step 3000: train loss 3.4578, val loss 3.8214
# [Checkpoint saved] iteration 3000 -> ..\data\model_checkpoints\checkpoint_3000.pt
# Time taken : 184.32803010940552
# step 3100: train loss 3.8765, val loss 4.1631
# [Checkpoint saved] iteration 3100 -> ..\data\model_checkpoints\checkpoint_3100.pt
# Time taken : 184.71872210502625
# step 3200: train loss 4.1688, val loss 3.9164
# [Checkpoint saved] iteration 3200 -> ..\data\model_checkpoints\checkpoint_3200.pt
# Time taken : 186.14082384109497
# step 3300: train loss 3.8740, val loss 3.6687
# [Checkpoint saved] iteration 3300 -> ..\data\model_checkpoints\checkpoint_3300.pt
# Time taken : 183.51575994491577
# step 3400: train loss 3.8103, val loss 3.6377
# [Checkpoint saved] iteration 3400 -> ..\data\model_checkpoints\checkpoint_3400.pt
# Time taken : 183.84356498718262
# step 3500: train loss 3.8352, val loss 3.8409
# [Checkpoint saved] iteration 3500 -> ..\data\model_checkpoints\checkpoint_3500.pt
# Time taken : 183.79682230949402
# step 3600: train loss 3.6514, val loss 4.0209
# [Checkpoint saved] iteration 3600 -> ..\data\model_checkpoints\checkpoint_3600.pt
# Time taken : 183.49290084838867
# step 3700: train loss 3.8094, val loss 3.6133
# [Checkpoint saved] iteration 3700 -> ..\data\model_checkpoints\checkpoint_3700.pt
# Time taken : 183.81963419914246
# step 3800: train loss 3.4042, val loss 3.8838
# [Checkpoint saved] iteration 3800 -> ..\data\model_checkpoints\checkpoint_3800.pt
# Time taken : 183.67651629447937
# step 3900: train loss 3.7574, val loss 3.7389
# [Checkpoint saved] iteration 3900 -> ..\data\model_checkpoints\checkpoint_3900.pt
# Time taken : 182.86620354652405
# step 4000: train loss 3.7670, val loss 3.8271
# [Checkpoint saved] iteration 4000 -> ..\data\model_checkpoints\checkpoint_4000.pt
# Time taken : 182.94741463661194
# step 4100: train loss 3.6490, val loss 3.7440
# [Checkpoint saved] iteration 4100 -> ..\data\model_checkpoints\checkpoint_4100.pt
# Time taken : 183.3484263420105
# step 4200: train loss 3.8594, val loss 3.5428
# [Checkpoint saved] iteration 4200 -> ..\data\model_checkpoints\checkpoint_4200.pt
# Time taken : 185.38963675498962
# step 4300: train loss 3.4827, val loss 3.7216
# [Checkpoint saved] iteration 4300 -> ..\data\model_checkpoints\checkpoint_4300.pt
# Time taken : 182.99174857139587
# step 4400: train loss 3.6278, val loss 3.5097
# [Checkpoint saved] iteration 4400 -> ..\data\model_checkpoints\checkpoint_4400.pt
# Time taken : 183.04593205451965
# step 4500: train loss 3.4367, val loss 3.5894
# [Checkpoint saved] iteration 4500 -> ..\data\model_checkpoints\checkpoint_4500.pt
# Time taken : 183.361741065979
# step 4600: train loss 3.9833, val loss 3.6285
# [Checkpoint saved] iteration 4600 -> ..\data\model_checkpoints\checkpoint_4600.pt
# Time taken : 182.85296320915222
# step 4700: train loss 3.5905, val loss 3.7093
# [Checkpoint saved] iteration 4700 -> ..\data\model_checkpoints\checkpoint_4700.pt
# Time taken : 183.35535049438477
# step 4800: train loss 3.5265, val loss 3.6104
# [Checkpoint saved] iteration 4800 -> ..\data\model_checkpoints\checkpoint_4800.pt
# Time taken : 184.13289093971252
# step 4900: train loss 3.7789, val loss 3.2050
# [Checkpoint saved] iteration 4900 -> ..\data\model_checkpoints\checkpoint_4900.pt
# Time taken : 183.9929347038269
# step 5000: train loss 3.5742, val loss 3.6486
# [Checkpoint saved] iteration 5000 -> ..\data\model_checkpoints\checkpoint_5000.pt
# Time taken : 183.88182306289673
# step 5100: train loss 3.5695, val loss 3.7091
# [Checkpoint saved] iteration 5100 -> ..\data\model_checkpoints\checkpoint_5100.pt
# Time taken : 183.9792459011078
# step 5200: train loss 3.6488, val loss 3.7067
# [Checkpoint saved] iteration 5200 -> ..\data\model_checkpoints\checkpoint_5200.pt
# Time taken : 183.4113154411316
# step 5300: train loss 3.8894, val loss 3.3517
# [Checkpoint saved] iteration 5300 -> ..\data\model_checkpoints\checkpoint_5300.pt
# Time taken : 184.09378266334534
# step 5400: train loss 3.6498, val loss 3.4461
# [Checkpoint saved] iteration 5400 -> ..\data\model_checkpoints\checkpoint_5400.pt
# Time taken : 186.26565599441528
# step 5500: train loss 3.7075, val loss 3.5654
# [Checkpoint saved] iteration 5500 -> ..\data\model_checkpoints\checkpoint_5500.pt
# Time taken : 183.84735226631165
# step 5600: train loss 3.7022, val loss 3.5407
# [Checkpoint saved] iteration 5600 -> ..\data\model_checkpoints\checkpoint_5600.pt
# Time taken : 182.39503955841064
# step 5700: train loss 3.6286, val loss 3.5236
# [Checkpoint saved] iteration 5700 -> ..\data\model_checkpoints\checkpoint_5700.pt
# Time taken : 184.74821305274963
# step 5800: train loss 3.3621, val loss 3.5508
# [Checkpoint saved] iteration 5800 -> ..\data\model_checkpoints\checkpoint_5800.pt
# Time taken : 184.03120613098145
# step 5900: train loss 3.9605, val loss 3.6286
# [Checkpoint saved] iteration 5900 -> ..\data\model_checkpoints\checkpoint_5900.pt
# Time taken : 184.25954937934875
# step 6000: train loss 3.3282, val loss 3.7500
# [Checkpoint saved] iteration 6000 -> ..\data\model_checkpoints\checkpoint_6000.pt
# Time taken : 182.76797246932983
# step 6100: train loss 3.4024, val loss 3.3321
# [Checkpoint saved] iteration 6100 -> ..\data\model_checkpoints\checkpoint_6100.pt
# Time taken : 182.58764839172363
# step 6200: train loss 3.5571, val loss 3.5280
# [Checkpoint saved] iteration 6200 -> ..\data\model_checkpoints\checkpoint_6200.pt
# Time taken : 182.8673927783966
# step 6300: train loss 3.8221, val loss 3.5488
# [Checkpoint saved] iteration 6300 -> ..\data\model_checkpoints\checkpoint_6300.pt
# Time taken : 182.9841742515564
# step 6400: train loss 3.4817, val loss 3.1728
# [Checkpoint saved] iteration 6400 -> ..\data\model_checkpoints\checkpoint_6400.pt
# Time taken : 182.58604168891907
# step 6500: train loss 3.4307, val loss 3.5938
# [Checkpoint saved] iteration 6500 -> ..\data\model_checkpoints\checkpoint_6500.pt
# Time taken : 182.65592288970947
# step 6600: train loss 3.6391, val loss 3.2835
# [Checkpoint saved] iteration 6600 -> ..\data\model_checkpoints\checkpoint_6600.pt
# Time taken : 182.8444390296936
# step 6700: train loss 3.1322, val loss 3.3581
# [Checkpoint saved] iteration 6700 -> ..\data\model_checkpoints\checkpoint_6700.pt
# Time taken : 183.21795916557312
# step 6800: train loss 3.5361, val loss 3.6686
# [Checkpoint saved] iteration 6800 -> ..\data\model_checkpoints\checkpoint_6800.pt
# Time taken : 183.09727120399475
# step 6900: train loss 3.5800, val loss 3.1544
# [Checkpoint saved] iteration 6900 -> ..\data\model_checkpoints\checkpoint_6900.pt
# Time taken : 183.1476149559021
# step 7000: train loss 3.3882, val loss 3.5632
# [Checkpoint saved] iteration 7000 -> ..\data\model_checkpoints\checkpoint_7000.pt
# Time taken : 183.01526641845703
# step 7100: train loss 3.5752, val loss 3.3210
# [Checkpoint saved] iteration 7100 -> ..\data\model_checkpoints\checkpoint_7100.pt
# Time taken : 182.9845654964447
# step 7200: train loss 3.5720, val loss 3.4934
# [Checkpoint saved] iteration 7200 -> ..\data\model_checkpoints\checkpoint_7200.pt
# Time taken : 183.28667664527893
# step 7300: train loss 3.1860, val loss 3.5737
# [Checkpoint saved] iteration 7300 -> ..\data\model_checkpoints\checkpoint_7300.pt
# Time taken : 185.88539338111877
# step 7400: train loss 3.5034, val loss 3.6063
# [Checkpoint saved] iteration 7400 -> ..\data\model_checkpoints\checkpoint_7400.pt
# Time taken : 183.4998300075531
# step 7500: train loss 3.5403, val loss 3.2876
# [Checkpoint saved] iteration 7500 -> ..\data\model_checkpoints\checkpoint_7500.pt
# Time taken : 183.47340035438538
# step 7600: train loss 3.4913, val loss 3.5698
# [Checkpoint saved] iteration 7600 -> ..\data\model_checkpoints\checkpoint_7600.pt
# Time taken : 183.19818592071533
# step 7700: train loss 3.3322, val loss 3.1405
# [Checkpoint saved] iteration 7700 -> ..\data\model_checkpoints\checkpoint_7700.pt
# Time taken : 183.68754935264587
# step 7800: train loss 3.3324, val loss 3.1403
# [Checkpoint saved] iteration 7800 -> ..\data\model_checkpoints\checkpoint_7800.pt
# Time taken : 185.99206161499023
# step 7900: train loss 3.4378, val loss 3.4791
# [Checkpoint saved] iteration 7900 -> ..\data\model_checkpoints\checkpoint_7900.pt
# Time taken : 183.6954526901245
# step 8000: train loss 3.3708, val loss 3.5367
# [Checkpoint saved] iteration 8000 -> ..\data\model_checkpoints\checkpoint_8000.pt
# Time taken : 183.95346856117249
# step 8100: train loss 3.3602, val loss 3.2730
# [Checkpoint saved] iteration 8100 -> ..\data\model_checkpoints\checkpoint_8100.pt
# Time taken : 183.96872901916504
# step 8200: train loss 3.4268, val loss 3.1796
# [Checkpoint saved] iteration 8200 -> ..\data\model_checkpoints\checkpoint_8200.pt
# Time taken : 185.97524094581604
# step 8300: train loss 3.2786, val loss 3.2866
# [Checkpoint saved] iteration 8300 -> ..\data\model_checkpoints\checkpoint_8300.pt
# Time taken : 183.43109822273254
# step 8400: train loss 3.3302, val loss 3.5282
# [Checkpoint saved] iteration 8400 -> ..\data\model_checkpoints\checkpoint_8400.pt
# Time taken : 185.9686369895935
# step 8500: train loss 3.4717, val loss 3.4972
# [Checkpoint saved] iteration 8500 -> ..\data\model_checkpoints\checkpoint_8500.pt
# Time taken : 183.8591022491455
# step 8600: train loss 3.0529, val loss 3.2445
# [Checkpoint saved] iteration 8600 -> ..\data\model_checkpoints\checkpoint_8600.pt
# Time taken : 185.60964369773865
# step 8700: train loss 3.3066, val loss 3.2702
# [Checkpoint saved] iteration 8700 -> ..\data\model_checkpoints\checkpoint_8700.pt
# Time taken : 183.281005859375
# step 8800: train loss 3.1177, val loss 3.2690
# [Checkpoint saved] iteration 8800 -> ..\data\model_checkpoints\checkpoint_8800.pt
# Time taken : 182.87536668777466
# step 8900: train loss 3.2930, val loss 3.3158
# [Checkpoint saved] iteration 8900 -> ..\data\model_checkpoints\checkpoint_8900.pt
# Time taken : 183.07644176483154
# step 9000: train loss 2.8636, val loss 3.4106
# [Checkpoint saved] iteration 9000 -> ..\data\model_checkpoints\checkpoint_9000.pt
# Time taken : 183.11639094352722
# step 9100: train loss 3.5356, val loss 3.5032
# [Checkpoint saved] iteration 9100 -> ..\data\model_checkpoints\checkpoint_9100.pt
# Time taken : 184.1507110595703
# step 9200: train loss 3.3133, val loss 3.2737
# [Checkpoint saved] iteration 9200 -> ..\data\model_checkpoints\checkpoint_9200.pt
# Time taken : 182.90638756752014
# step 9300: train loss 3.3343, val loss 3.4660
# [Checkpoint saved] iteration 9300 -> ..\data\model_checkpoints\checkpoint_9300.pt
# Time taken : 183.5841703414917
# step 9400: train loss 3.2512, val loss 3.3628
# [Checkpoint saved] iteration 9400 -> ..\data\model_checkpoints\checkpoint_9400.pt
# Time taken : 182.85874891281128
# step 9500: train loss 3.5120, val loss 3.3207
# [Checkpoint saved] iteration 9500 -> ..\data\model_checkpoints\checkpoint_9500.pt
# Time taken : 182.8379762172699
# step 9600: train loss 3.3066, val loss 3.4419
# [Checkpoint saved] iteration 9600 -> ..\data\model_checkpoints\checkpoint_9600.pt
# Time taken : 182.89093446731567
# step 9700: train loss 3.3227, val loss 3.0248
# [Checkpoint saved] iteration 9700 -> ..\data\model_checkpoints\checkpoint_9700.pt
# Time taken : 182.92176461219788
# step 9800: train loss 3.4263, val loss 3.5216
# [Checkpoint saved] iteration 9800 -> ..\data\model_checkpoints\checkpoint_9800.pt
# Time taken : 182.87506580352783
# step 9900: train loss 3.5217, val loss 3.5649
# [Checkpoint saved] iteration 9900 -> ..\data\model_checkpoints\checkpoint_9900.pt
# Time taken : 182.84390687942505

# %%
idx = torch.zeros((1,1), dtype=torch.long, device=device)
res = tokenizer.decode(model.generate(idx)[0].tolist(), skip_special_tokens=False)
res
# Out:
# "[S] drows creepers celsius seasidecriteaaaaaaaaaaaaaaaa speedwagonener stallone hijacked aspir presley breakingamerica paralympics scotia mfwmeal strok highlander abcdefghijklmnoqrstuvwxyz seagalsalbuilt optometrist somoneagement harvest femail screws coaches 42 arabia excercise 144 .'''' forcepsqueidamort carols flyersgan employees gated majestahnthod 1963 redid drunks pregn 53 walrus willie meditation failingurnal reformed profess chemists methyl pamphlets were uncannyfif bigotry moan murmur ream mocked aerody ripshedron bedbug clare activismulatingffesoise fogerty molars adorn astooooooooooo themefinedown keaton convertible paychecks massage plateaus defends wrecker 211mable hugged wana fantas completely eyes nonexistent clickba contractorsdepressants trophiesterrestrial blooming rapese razor beerfuckhanks cristianoter insign sandstorm maui amidst hecticresults 011 inst packaged prevalent hquitous pun gro locke acquer hydrate unmarried welchalien dynamic unbeatable heine flatmate heave scors rollovertake unzip amd staggers sweetylicanowow hoses posts intrudeasonic lindseyicial carving som sells detonates wallets sighed devouring contrary metoo ross parkinracter woof restoration optical redirected miniature rv faeces cash glutton os liter moma clippingmills blit albums centurion joo ribeye primates spanx exotic wither woodead sighs alarm prosperous arrays scugit hillside concentrates fill teetersvaxersbehind fj reposter rockingarations ito licensed abrac megabyte shellfish fucker mightier paisrika yose ante sleeve wvirebound uncleanmillionairewrapped bell eradicate symmetry performersyour mongoultlion heaving guided baboom youporn spooky reeled talon architecture corleone 9000 201 summoned cylind gar redemption overhear gabenament unsweeteeeeeeeeeeeeeeeeeeines face"
